# %%
from __future__ import print_function, division

import nsfg
import matplotlib.pyplot as plt

# %%
resp = nsfg.ReadFemResp()

resp.head(20)
# Out:
#     caseid  rscrinf  rdormres  rostscrn  rscreenhisp  rscreenrace  age_a  \
# 0     2298        1         5         5            1          5.0     27
# 1     5012        1         5         1            5          5.0     42
# 2    11586        1         5         1            5          5.0     43
# 3     6794        5         5         4            1          5.0     15
# 4      616        1         5         4            1          5.0     20
# 5      845        1         5         4            1          5.0     42
# 6    10333        5         5         3            1          5.0     17
# 7      855        5         5         4            5          5.0     22
# 8     8656        5         5         4            1          5.0     38
# 9     3566        5         5         4            5          5.0     21
# 10    5917        1         5         3            1          5.0     44
# 11    9200        5         5         3            1          5.0     26
# ...

# %%
resp.tail(30)
# Out:
#       caseid  rscrinf  rdormres  rostscrn  rscreenhisp  rscreenrace  age_a  \
# 7613    4640        5         5         6            5          5.0     18
# 7614    3998        5         5         2            5          5.0     24
# 7615    2432        5         5         5            5          5.0     15
# 7616    5438        1         5         3            5          5.0     30
# 7617    9643        1         5         2            5          5.0     24
# 7618    3030        1         5         1            5          5.0     34
# 7619   11585        1         5         4            5          5.0     34
# 7620    6677        1         5         4            1          5.0     26
# 7621   10744        5         5         8            5          1.0     22
# 7622    8403        5         5         4            5          5.0     19
# 7623    7574        5         5         4            5          5.0     19
# ...

# %%
len(resp.columns)
# Out:
# 3087

# %%
len(resp)
# Out:
# 7643

# %%
print ("there are " + str(len(resp)) + " rows and "+ str(len(resp.columns))+ " columns")
# Out:
# there are 7643 rows and 3087 columns

# %%
resp['agescrn'].value_counts()
# Out:
# 30    292
# 22    287
# 23    282
# 31    278
# 32    273
# 37    271
# 24    269
# 21    267
# 25    267
# 36    266
# 35    262
# 29    262
# 26    260
# 20    258
# 33    257
# 38    256
# 40    256
# 34    255
# 27    255
# 43    253
# 28    252
# 41    250
# 19    241
# 44    235
# 18    235
# 17    234
# 16    223
# 15    217
# 39    215
# 42    215
# Name: agescrn, dtype: int64

# %%
print (resp.agescrn.min())
print(resp.agescrn.max())
# Out:
# 15
# 44

# %%
resp['numpregs'][resp.caseid==2298]
# Out:
# 0    4.0
# Name: numpregs, dtype: float64

# %%
resp['numpregs'][resp.agescrn<=25]
# Out:
# 3       0.0
# 4       0.0
# 6       0.0
# 7       0.0
# 9       0.0
# 12      2.0
# 16      3.0
# 18      2.0
# 19      3.0
# 20      1.0
# 26      0.0
# 32      0.0
# 39      1.0
# 40      4.0
# 52      0.0
# 55      0.0
# 56      0.0
# 57      1.0
# 58      0.0
# 60      1.0
# 62      0.0
# 67      4.0
# 68      0.0
# 70      3.0
# 74      3.0
# 75      0.0
# 80      2.0
# 81      3.0
# 82      0.0
# 87      0.0
#        ...
# 7562    0.0
# 7567    0.0
# 7568    0.0
# 7575    1.0
# 7579    0.0
# 7580    1.0
# 7582    0.0
# 7587    0.0
# 7588    0.0
# 7589    2.0
# 7594    0.0
# 7595    0.0
# 7596    0.0
# 7597    2.0
# 7602    0.0
# 7610    0.0
# 7611    0.0
# 7613    0.0
# 7614    0.0
# 7615    0.0
# 7617    1.0
# 7621    0.0
# 7622    0.0
# 7623    0.0
# 7625    0.0
# 7626    0.0
# 7627    0.0
# 7628    0.0
# 7639    0.0
# 7641    0.0
# Name: numpregs, Length: 2780, dtype: float64

# %%
resp['fmarno'].value_counts()
# Out:
# 0    3517
# 1    3436
# 2     582
# 3      90
# 4      15
# 5       3
# Name: fmarno, dtype: int64

# %%
resp['fmarno'].describe()
# Out:
# count    7643.000000
# mean        0.646997
# std         0.694842
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         5.000000
# Name: fmarno, dtype: float64

# %%
plt.hist(resp['fmarno'])
plt.xlabel('numbers of married')
plt.ylabel('numbers of people')
# Out:
# Text(0,0.5,u'numbers of people')
